# %% [markdown]
# <a href="https://colab.research.google.com/github/francejules22/ArchitectWebsiteWithGit/blob/master/Flower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Francis Jules C. Espartero BSCS 3B

# %% [markdown]
# Importing TensorFlow and other libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# Download and Explore the dataset

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos',origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir)
# Out:
# ...
# 228827136/228813984 [==============================] - 2s 0us/step

# %% [markdown]
# After downloading, you should now have a copy of the dataset available. There are 3,670 total images:

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %% [markdown]
# Here are some roses:

# %%
roses = list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7FE03153AB10>

# %%
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7FE03320C2D0>

# %%
PIL.Image.open(str(roses[2]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7FE02FBD2A10>

# %% [markdown]
# And some tulips:

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x335 at 0x7FE02FB64550>

# %%
PIL.Image.open(str(tulips[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=159x240 at 0x7FE02FB73950>
